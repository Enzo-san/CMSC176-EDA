# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as pltt

# %%
data = pd.read_csv(r"diabetic_data.csv")

# %%
data.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
data.tail()
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
data.shape
# Out:
# (101766, 50)

# %%
data.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
data.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
data.nunique()
# Out:
# encounter_id                101766
# patient_nbr                  71518
# race                             6
# gender                           3
# age                             10
# weight                          10
# admission_type_id                8
# discharge_disposition_id        26
# admission_source_id             17
# time_in_hospital                14
# payer_code                      18
# medical_specialty               73
# num_lab_procedures             118
# num_procedures                   7
# num_medications                 75
# number_outpatient               39
# number_emergency                33
# number_inpatient                21
# diag_1                         717
# diag_2                         749
# diag_3                         790
# number_diagnoses                16
# max_glu_serum                    4
# A1Cresult                        4
# metformin                        4
# repaglinide                      4
# nateglinide                      4
# ...

# %%
#clean data

# %%
data.isnull().sum()
# Out:
# encounter_id                0
# patient_nbr                 0
# race                        0
# gender                      0
# age                         0
# weight                      0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# payer_code                  0
# medical_specialty           0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# ...

# %%
patient_info = data.drop([''])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-139-694ae9f2a54b> in <module>
# ----> 1 patient_info = data.drop([''])
#
# c:\users\enzo\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4167             level=level,
#    4168             inplace=inplace,
# -> 4169             errors=errors,
#    4170         )
#    4171
#
# c:\users\enzo\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3882         for axis, labels in axes.items():
#    3883             if labels is not None:
# -> 3884                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3885
#    3886         if inplace:
#
# ...

# %%
s = data["race"]
pd.value_counts(s).plot(kind="barh", title="RACE", figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'RACE'}>

# %%
s = data["age"]
pd.value_counts(s).plot(kind="barh", title="AGE")
# Out:
# <AxesSubplot:title={'center':'AGE'}>

# %%
s = data["medical_specialty"]
pd.value_counts(s).plot(kind="bar", title="MEDICAL SPECIALTY", figsize=(20,15))
# Out:
# <AxesSubplot:title={'center':'MEDICAL SPECIALTY'}>

# %%
pd.value_counts(s)
# Out:
# ?                                   49949
# InternalMedicine                    14635
# Emergency/Trauma                     7565
# Family/GeneralPractice               7440
# Cardiology                           5352
#                                     ...
# Proctology                              1
# Perinatology                            1
# Dermatology                             1
# Surgery-PlasticwithinHeadandNeck        1
# Psychiatry-Addictive                    1
# Name: medical_specialty, Length: 73, dtype: int64

# %%
s = data["gender"]
pd.value_counts(s).plot(kind="pie", title="GENDER")
pd.value_counts(s)
# Out:
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: gender, dtype: int64

# %%
#s = pd.DataFrame(np.random.rand(15, 4), columns=['No', 'Steady', 'Up', 'Down'])
#s.plot.bar(stacked=True)
#pd.value_counts(s).plot(kind="bar", title="metformin", stacked=True)
#pd.value_counts(s)

meds=["Metformin", "Repaglinide", "Nateglinide", "Chlorpropamide", "Glimepiride", "Acetohexamide"
     ,"Glipizide", "Glyburide", "Tolbutamide", "Pioglitazone", "Rosiglitazone", "Acarbose"
     ,"Miglitol", "Troglitazone", "Tolazamide", "Examide", "Citoglipton", "Insulin"
     ,"Glyburide-Metformin", "Glipizide-Metformin", "Glimepiride-Pioglitazone"
     ,"Metformin-Rosiglitazone", "Metformin-Pioglitazone"]

Down=[575, 45, 11, 1, 194, 0, 560, 564, 0, 118, 87, 3, 5, 0, 0, 0, 0, 12218, 6, 0, 0, 0, 0]
No=[81778, 100227, 101063, 101680, 96575, 101765, 89090, 91116, 101743, 94438, 95401, 101458, 101728
   ,101763, 101727, 101766, 101766, 47383, 101060, 101753, 101765, 101764, 101765]
Steady=[18346, 1384, 668, 79, 4670, 1, 11356, 9274, 23, 6976, 6100, 295, 31, 3, 38, 0, 0, 30849
       ,692, 13, 1, 2, 1]
Up=[1067, 110, 24, 6, 327, 0, 770, 812, 0, 234, 178, 10, 2, 0, 1, 0, 0, 11316, 8, 0, 0, 0, 0]

pltt.figure(figsize=(16, 10))
pltt.barh(meds, No, 0.4, label="No")
pltt.barh(meds, Steady, 0.4, label="Steady")
pltt.barh(meds, Up, 0.4, label="Up")
pltt.barh(meds, Down, 0.4, label="Down")
pltt.xlabel("Type")
pltt.ylabel("Medicines")
pltt.legend()
pltt.show()

# %%
s = data["repaglinide"]
pd.value_counts(s)
# Out:
# No        100227
# Steady      1384
# Up           110
# Down          45
# Name: repaglinide, dtype: int64

# %%
pltt.figure(figsize=(16, 6))
g = sns.countplot(data=data,x='gender',hue='age')
#g.legend_.remove() #pwede nyo i uncomment kung gagawan nyo screenshot

# %%
pltt.figure(figsize=(16, 6))
sns.countplot(data=data,x='race',hue='gender')
# Out:
# <AxesSubplot:xlabel='race', ylabel='count'>

# %%
s = data["admission_type_id"]
pd.value_counts(s)
# Out:
# 1    53990
# 3    18869
# 2    18480
# 6     5291
# 5     4785
# 8      320
# 7       21
# 4       10
# Name: admission_type_id, dtype: int64

# %%
s = data["discharge_disposition_id"]
pd.value_counts(s)
# Out:
# 1     60234
# 3     13954
# 6     12902
# 18     3691
# 2      2128
# 22     1993
# 11     1642
# 5      1184
# 25      989
# 4       815
# 7       623
# 23      412
# 13      399
# 14      372
# 28      139
# 8       108
# 15       63
# 24       48
# 9        21
# 17       14
# 16       11
# 19        8
# 10        6
# 27        5
# 12        3
# 20        2
# Name: discharge_disposition_id, dtype: int64

# %%
s = data["admission_source_id"]
pd.value_counts(s)
# Out:
# 7     57494
# 1     29565
# 17     6781
# 4      3187
# 6      2264
# 2      1104
# 5       855
# 3       187
# 20      161
# 9       125
# 8        16
# 22       12
# 10        8
# 11        2
# 14        2
# 25        2
# 13        1
# Name: admission_source_id, dtype: int64

# %%
pltt.figure(figsize=(16, 6))
g = sns.countplot(data=data,x='age',hue='num_medications')
#g.legend_.remove() #pwede nyo i uncomment kung gagawan nyo screenshot

# %%
pltt.figure(figsize=(16, 6))
g = sns.countplot(data=data,x='age',hue='num_lab_procedures')
#g.legend_.remove() #pwede nyo i uncomment kung gagawan nyo screenshot

# %%
pltt.figure(figsize=(16, 6))
g = sns.countplot(data=data,x='age',hue='number_diagnoses')
#g.legend_.remove() #pwede nyo i uncomment kung gagawan nyo screenshot
